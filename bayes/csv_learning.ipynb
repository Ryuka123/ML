# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("sample.csv")
df.head(5)
# Out:
#       Number  Age     Sex      Source  \
# 0  151001001   28    male  Outpatient
# 1  151001003   65  female  Outpatient
# 2  151001006   63  female  Outpatient
# 3  151001007   30  female  Outpatient
# 4  151001012   67  female  Outpatient
#
#                                   Diagnosis  Sleep quality  Sleep latency  \
# 0                             Schizophrenia              1              0
# 1                             Schizophrenia              2              3
# 2                                Depression              1              1
# 3                                Depression              3              3
# 4  Mental disorders due to vascular disease              1              0
#
#    Sleep time  Sleep efficiency  Sleep disorder  Hypnagogue  \
# 0           0                 0               2           2
# 1           2                 1               2           2
# 2           1                 1               0           2
# ...

# %%
df.tail(5)
# Out:
#          Number  Age     Sex      Source               Diagnosis  \
# 6344  170929113   17  female  Outpatient  Anxiety,Sleep disorder
# 6345  170929116   49    male  Outpatient   Somatization Disorder
# 6346  170929141   68  female  Outpatient        Anxiety disorder
# 6347  170930010   41  female  Outpatient              Depression
# 6348  170930067   34    male  Outpatient        Anxiety disorder
#
#       Sleep quality  Sleep latency  Sleep time  Sleep efficiency  \
# 6344              1              2           2                 0
# 6345              2              2           3                 3
# 6346              1              1           2                 1
# 6347              3              2           3                 3
# 6348              2              2           2                 0
#
#       Sleep disorder  Hypnagogue  Daytime dyfunction
# 6344               1           3                   2
# 6345               1           0                   1
# ...

# %%
df[3:6] # DataFrame是可以进行切片的
# Out:
#       Number  Age     Sex      Source  \
# 3  151001007   30  female  Outpatient
# 4  151001012   67  female  Outpatient
# 5  151001013   53    male  Outpatient
#
#                                   Diagnosis  Sleep quality  Sleep latency  \
# 3                                Depression              3              3
# 4  Mental disorders due to vascular disease              1              0
# 5                 Sleep disorder,Depression              2              3
#
#    Sleep time  Sleep efficiency  Sleep disorder  Hypnagogue  \
# 3           3                 3               3           3
# 4           2                 1               1           3
# 5           0                 3               2           0
#
#    Daytime dyfunction
# 3                   2
# 4                   1
# 5                   2

# %%
df["Diagnosis"].value_counts() # 得出各种病症的数量
# Out:
# Sleep disorder                                                      1699
# Depression                                                          1472
# Anxiety disorder                                                     861
# Anxiety                                                              402
# Mixed Anxiety And Depression                                         368
# Bipolar Affective Disorder                                           132
# Non-Organic Insomnia                                                 106
# Recurrent Depressive Disorder                                         74
# Adjustment Disorder                                                   58
# Anxiety,Sleep disorder                                                50
# Schizophrenia                                                         46
# Consultation                                                          36
# Sleep disorder,Depression                                             33
# ...

# %%
df["Diagnosis"].describe() # 描述这一个属性的大概统计数字
# Out:
# count               6348
# unique               289
# top       Sleep disorder
# freq                1699
# Name: Diagnosis, dtype: object

# %%
df["Age"].describe() # 描述年龄属性
# Out:
# count    6349.000000
# mean       39.892266
# std        14.451461
# min        16.000000
# 25%        28.000000
# 50%        38.000000
# 75%        51.000000
# max        87.000000
# Name: Age, dtype: float64
